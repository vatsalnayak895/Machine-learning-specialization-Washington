# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import numpy as np
# %matplotlib inline

# %%
house_data=pd.read_csv('/home/fractaluser/Desktop/Untitled Folder 2/ml_splzn_coursera/Week 2/home_data.csv')

# %%
house_data.head()
#house_data.shape
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.lmplot('sqft_living','price',data=house_data,fit_reg=True)
plt.show()

# %%
plt.scatter(x=house_data['sqft_living'],y=house_data['price'])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
random.seed(100)
train_data,test_data = train_test_split(house_data,test_size=0.2,random_state=0)

# %%
test_data['price'].mean()
# Out:
# 529242.6106870229

# %%
train_data['price'].mean()
# Out:
# 542799.8383458647

# %%
house_data['price'].mean()
# Out:
# 540088.1419053348

# %%
plt.figure(figsize=(5,5))
sns.jointplot('sqft_living','price',data=house_data,kind='hex')#,kde=True)
plt.show()

# %%
plt.plot(house_data['sqft_living'],house_data['price'],'.')
#plt.show()

# %%
plt.figure(figsize=(25,10))
sns.boxplot('zipcode','price',data=test_data)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
x=house_data['sqft_living']
y=house_data['price']
X=x[:,np.newaxis]
regressor.fit(X,y)
plt.scatter(x,y)
plt.plot(x,regressor.predict(X),'r-')

# %%
regressor.predict(2650)
# Out:
# array([ 700071.71125207])
